# %%
from IPython.display import Audio, Video

from src.utils import (
    download_youtube_video,
    process_video,
    generate_descriptions,
    generate_narration,
    generate_audio,
    overlay_audio_on_video,
    get_video_length,
)

from src.prompts import (
    BRAZILLIAN_NARRATIVE, 
    SNAPSHOT_ANALYSIS
)

# %%
youtube_url = 'https://www.youtube.com/watch?v=nEE2ZWwmqBc&ab_channel=Theguywiththelockface'  # replace with your YouTube video URL
video_path = download_youtube_video(youtube_url, 'videos')
base64Frames = process_video(video_path)
video_length = get_video_length(video_path)

print(len(base64Frames), "frames read.")
print("Video length:", video_length, "seconds.")
# Out:
# 550 frames read.
# Video length: 18.85 seconds.

# %%
Video(video_path)
# Out:
# <video src="/Users/atom/Github/soccer_narrator/videos/Ankara Messi but with phonk.mp4" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
print(SNAPSHOT_ANALYSIS)
# Out:
# Analyze this standalone image, detailing the football action it captures. Describe player movements, ball location, and immediate context, like a tackle, pass, or goal attempt, as if this is the only moment you're aware of. Be structured and concise, and avoid referencing past or future events. Max 50 words.

# %%
print(BRAZILLIAN_NARRATIVE)
# Out:
# These are frames of a video. Create a short voiceover script in the style of a super excited brazilian sports narrator who is narrating his favorite match. Your output must be in english. You must only output the narration since eall the text output will be synthesized to audio. When the ball goes into the net, you must scream GOL either once or multiple times.

# %%
descriptions = generate_descriptions(
    base64Frames,
    frame_sampling_rate=30,
    prompt=SNAPSHOT_ANALYSIS,
)
print(descriptions)
# Out:
# Frame 0: The image shows a live football match where a player in blue appears to control the ball, facing opposition from a player in yellow. Other players are positioning themselves, likely anticipating a pass or movement to progress the play. It's a midfield encounter without immediate scoring threat.
# Frame 30: In the image, a player in a yellow jersey controls the ball near the center circle, facing a slight opposition from one player in a blue jersey. Teammates in both colors are positioned around the field, seemingly ready for a pass or to move to defend.
# Frame 60: The image shows a football match in progress. Players are scattered, suggesting open play. The ball is not visible, but players' attention near the center circle hints it may be off-camera nearby. No immediate tackle or goal attempt is apparent; players seem to be positioning for a pass or interception.
# Frame 90: Player in blue controls the ball, facing away from an approaching opponent in yellow. The blue player appears to be preparing to pass or turn, while teammates position for support. Ball is central, near the circle—likely a midfield transition or setup phase. No immediate goal action.
# Frame 120: The image shows a soccer match in progress. Players are positioned in the midfield with the team in yellow likely in possession as the player at the center appears to control the ball. Positions suggest an attempt to build an attack, while the opposition is organizing defense.
# Frame 150: In the image, a player in blue is dribbling the ball, displaying close control, while two opponents in yellow close in, preparing to challenge or intercept. The dribbler's focus is on maintaining possession, hinting at an ongoing midfield play or an attacking maneuver.
# Frame 180: The image shows a player in a blue and red kit dribbling the ball with pace, evading an opposing player in a yellow kit who appears to be in the process of attempting a tackle or interception. The ball is closely controlled by the player's left foot.
# Frame 210: A player in blue and red is in possession, dribbling forward. A player in yellow is behind, possibly attempting to catch up or tackle. The ball is closely controlled by the dribbling player's left foot, indicating an ongoing offensive play.
# Frame 240: A player in blue is dribbling forward with the ball, closely followed by two opponents in yellow. The dribbler is looking to advance or pass as two teammates trail the play. No immediate challenge is occurring, but the situation is dynamic with potential for a defensive tackle or offensive play.
# Frame 270: I'm sorry, but I can't provide details about the image as it seems to be missing or there might be an error. If you could provide the image again, I'd be happy to help analyze the football action captured.
# Frame 300: The image shows a footballer in blue controlling the ball, shielding it from a player in yellow. They are inside the penalty box, suggesting an attacking play. The blue player's body orientation implies an attempt to create space for a shot or pass. No other action is observable.
# Frame 330: The image captures a football player in white dribbling towards the goal at pace, with a defender in blue close behind attempting to catch up. The ball is at the feet of the attacker. The action suggests a potential scoring opportunity is developing.
# Frame 360: In the image, a player in yellow seems to have just kicked the ball towards the goal, attempting a shot. A goalkeeper in green is diving to the right, poised to make a save. Two defenders in blue are nearby, one trailing the shooter. The ball is mid-flight, close to goal.
# Frame 390: A player in blue is executing a diving header near the goal, while a goalkeeper in yellow is in mid-air, attempting a save. The ball is in front of the player in blue. No opposing players are in the immediate vicinity, indicating a potential scoring opportunity.
# Frame 420: The image shows a football match in progress with a defender closely marking an opponent who appears to be receiving or controlling the ball. The goalkeeper is attentive, positioned near the goal line. The ball is in the air, and a potential goal-scoring moment seems imminent.
# Frame 450: The image shows a football player in a blue kit extending his foot, likely making contact with the ball near the goal. The opposition in yellow seems to be reacting to the play. Likely scenario: an attempted goal or a crucial pass in the penalty area.
# Frame 480: The image is too blurry to provide a detailed analysis of the football action. It features a player, presumably in motion, but specifics such as ball location, player movements, and immediate context cannot be accurately described due to the image's low quality.
# Frame 510: Sorry, the image provided does not display any football action, player movements, ball location, or context related to a football game. It only shows the logo of "CapCut," which appears to be a watermark indicating the video editing software used.
# Frame 540: The image displays the CapCut logo on a black background. There is no football action, player movements, ball location, or any sports-related context provided in this image. It appears to be a placeholder or introductory screen for a video editing application.

# %%
voiceover_narration = generate_narration(
    descriptions,
    prompt=BRAZILLIAN_NARRATIVE,
    max_tokens=100, # change this to control the length of the narration
)
print(voiceover_narration)
# Out:
# Oh my friends, hold on to your seats because this match is electric! We're in the heart of the game, midfield action is intense, players are jostling for possession, but wait—there's a breakaway! A magnificent dribble by the player in blue, he's navigating through defenders like they're cones. The crowd is roaring, can you feel the energy?! Prepare yourselves, we're approaching the box! Shot on goal! Is this the moment? GOL! GOL

# %%
audio = generate_audio(voiceover_narration, model='tts-1-hd', voice='echo', output_dir='audio')
Audio(audio)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
overlay_audio_on_video(video_path, audio, 'output.mp4')
# Out:
# Moviepy - Building video output.mp4.
# MoviePy - Writing audio in outputTEMP_MPY_wvf_snd.mp3
# MoviePy - Done.
# Moviepy - Writing video output.mp4
# Moviepy - Done !
# Moviepy - video ready output.mp4
# 'output.mp4'

# %%
Video('output.mp4')
# Out:
# <video src="output.mp4" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>
